# %%
# Data management and investigation
import pandas as pd
import numpy as np
import missingno as msno
from plotnine import *
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

from functools import reduce

# %%
# import 2019 reliability, net metering, energy efficiency, advanced metering infrastructure, demand response, and service territory data
reliability_19 = pd.read_excel("Data/Reliability_2019.xlsx", 
                               header = 1)
net_metering_19 = pd.read_excel("Data/Net_Metering_2019.xlsx", 
                                header = [0,1,2])
efficiency_19 = pd.read_excel("Data/Energy_Efficiency_2019.xlsx", 
                              header = [0,1,2])
demand_response_19 = pd.read_excel("Data/Demand_Response_2019.xlsx", 
                              header = [0,1,2])
territory_19 = pd.read_excel("Data/Service_Territory_2019.xlsx")
utility_19 = pd.read_excel("Data/Sales_Ult_Cust_2019.xlsx", 
                                header = [0,1,2])

# %%
# Combine the headers together to describe each column
net_metering_19.columns = net_metering_19.columns.map(' - '.join)
efficiency_19.columns = efficiency_19.columns.map(' - '.join)
demand_response_19.columns = demand_response_19.columns.map(' - '.join)
utility_19.columns = utility_19.columns.map(' - '.join)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# only grab the columns I want from each dataframe
reliability_19 = reliability_19[['Utility Number',
              'Utility Name', 
              'State',
              'Ownership',
              'SAIDI Without MED',
              'SAIFI Without MED', 
              'CAIDI Without MED']].dropna()

# %%
reliability_19.columns = ['no', 'name', 'state','type','saidi_nomed', 'saifi_nomed', 'caidi_nomed']

# %%
net_metering_19 = net_metering_19[['Utility Characteristics - Unnamed: 3_level_1 - Utility Name',
                                   'Utility Characteristics - Unnamed: 1_level_1 - State',
                'Photovoltaic - Energy Sold Back MWh - Total',
                'Wind - Energy Sold Back MWh - Total',
                'All Technologies - Energy Sold Back MWh - Total',
                ]].dropna()

# %%
net_metering_19.columns = ['name', 'state','pv_mwh', 'wind_mwh', 'nm_mwh']

# %%
efficiency_19 = efficiency_19[['Utility Characteristics - Unnamed: 2_level_1 - Utility Name',
                               'Utility Characteristics - Unnamed: 4_level_1 - State',
                  'Reporting Year Incremental Annual Savings - Energy Savings (MWh) - Total']].dropna()

# %%
efficiency_19.columns = ['name','state','ee_mwh']

# %%
demand_response_19 = demand_response_19[['Utility Characteristics - Unnamed: 2_level_1 - Utility Name',
                                         'Utility Characteristics - Unnamed: 4_level_1 - State',
                    'Yearly Energy and Demand Savings - Number of Customers Enrolled - Total',
                    'Yearly Energy and Demand Savings - Energy Savings (MWh) - Total']].dropna()

# %%
demand_response_19.columns = ['name', 'state','dem_res_customers', 'dem_res_mwh']

# %%
territory_19 = territory_19[['Utility Name',
             'State',
             'County']]

# %%
territory_19.columns = ['name', 'state', 'county']

# %%
utility_19 = utility_19[['Utility Characteristics - Unnamed: 2_level_1 - Utility Name',
                         'Utility Characteristics - Unnamed: 6_level_1 - State',
                         'TOTAL - Sales - Megawatthours',
                         'TOTAL - Customers - Count']]

# %%
utility_19.columns = ['name', 'state','total_mwh','total_cust']

# %%
demand_response_19.shape
# Out:
# (452, 4)

# %%
# merge all the lists together by utility name 
df_list = [utility_19, reliability_19, net_metering_19, efficiency_19, demand_response_19]
df_19 = reduce(lambda left,right: pd.merge(left,right,on=['name','state'], how='outer'), df_list)

# %%
# drop the duplicate rows 
df_19 = df_19[~df_19.duplicated(['name', 'state'])]

# %% [markdown]
# Here, I did a check on a random sample of 6 observations across categories to make sure everything looked good. When there's a NA for any of the reliability metrics, that means that data was missing from the survey, and I cannot simply impute with 0's – that would incorrectly be assuming that they had no system interruptions. My best option is to simply drop these rows, since they lack my outcome variable.

# %%
df_19.sample(6)
# Out:
#                                 name state  total_mwh  total_cust       no  \
# 1435        Lake Mills Light & Water    WI    62528.0      4210.0      NaN
# 843                 City of Fairbury    NE    83042.0      3064.0      NaN
# 3129      City of Minneapolis - (KS)    KS    16917.0      1103.0      NaN
# 1487         City of Leesburg - (FL)    FL   494267.0     26440.0  10868.0
# 2390  San Bernard Electric Coop, Inc    TX   700011.0     28911.0  16638.0
# 3800    Inspire Energy Holdings, LLC    MA   145079.0     20282.0      NaN
#
#              type saidi_nomed saifi_nomed caidi_nomed  pv_mwh  wind_mwh  \
# 1435          NaN         NaN         NaN         NaN    0.00       0.0
# 843           NaN         NaN         NaN         NaN    0.00       0.0
# 3129          NaN         NaN         NaN         NaN     NaN       NaN
# 1487    Municipal           .           .           .  270.23       0.0
# 2390  Cooperative       100.7       1.202      83.777    0.00       0.0
# 3800          NaN         NaN         NaN         NaN     NaN       NaN
#
#       nm_mwh  ee_mwh  dem_res_customers  dem_res_mwh
# 1435    0.00     NaN                NaN          NaN
# 843     0.00     NaN                NaN          NaN
# 3129     NaN     NaN                NaN          NaN
# 1487  270.23  69.132                NaN          NaN
# 2390    0.00     NaN                NaN          NaN
# 3800     NaN     NaN                NaN          NaN

# %%
# drop all the entries where my outcome variable is not present (SAIDI, SAIFI and CAIDI are same – I checked)
df_19 = df_19[~df_19.saidi_nomed.isna()]

# %%
# remove those missing total customer data and total megawatthours
df_19 = df_19[~df_19.total_mwh.isna()]
df_19 = df_19[~df_19.total_cust.isna()]

# %%
df_19.isna().sum(axis=0)
# Out:
# name                   0
# state                  0
# total_mwh              0
# total_cust             0
# no                     0
# type                   0
# saidi_nomed            0
# saifi_nomed            0
# caidi_nomed            0
# pv_mwh               309
# wind_mwh             309
# nm_mwh               309
# ee_mwh               740
# dem_res_customers    858
# dem_res_mwh          858
# dtype: int64

# %%
df_19
# Out:
#                                        name state  total_mwh  total_cust  \
# 3                       A & N Electric Coop    MD     2623.0       316.0
# 4                       A & N Electric Coop    VA   701387.0     35618.0
# 6                       Adams Electric Coop    IL   176102.0      8931.0
# 7              Adams-Columbia Electric Coop    WI   515186.0     37607.0
# 16                   Agralite Electric Coop    MN   238558.0      5251.0
# ...                                     ...   ...        ...         ...
# 3594             City of Winter Park - (FL)    FL   425022.0     15565.0
# 3726           PUD No 1 of Jefferson County    WA   376212.0     19742.0
# 4170          CKenergy Electric Cooperative    OK   654238.0     25684.0
# 4183  Upper Michigan Energy Resources Corp.    MI  1610240.0     36818.0
# 4192      Southern Pioneer Electric Company    KS   817910.0     16939.0
#
#            no                   type saidi_nomed saifi_nomed caidi_nomed  \
# 3        84.0            Cooperative           .           .           .
# 4        84.0            Cooperative           .           .           .
# 6        97.0            Cooperative      169.74        1.29     131.581
# 7       108.0            Cooperative       139.9        0.95     147.263
# 16      155.0            Cooperative     128.759       1.181     109.025
# ...       ...                    ...         ...         ...         ...
# 3594  58124.0              Municipal           .           .           .
# 3726  59013.0  Political Subdivision         291        2.04     142.647
# 4170  60482.0            Cooperative           .           .           .
# 4183  60631.0         Investor Owned         238         1.5     158.667
# 4192  60839.0            Cooperative      106.41           .           .
#
#        pv_mwh  wind_mwh   nm_mwh  ee_mwh  dem_res_customers  dem_res_mwh
# 3         NaN       NaN      NaN     NaN               35.0         1.05
# 4       0.000     0.000    0.000     NaN             2101.0        63.03
# 6       0.000     0.000    0.000     NaN             4402.0         0.00
# 7     705.775    22.235  728.010     NaN             4781.0     13647.36
# 16      0.000     0.000    0.000     NaN                NaN          NaN
# ...       ...       ...      ...     ...                ...          ...
# 3594  401.337     0.000  401.337   15.18                NaN          NaN
# 3726    0.000     0.000    0.000  651.00                NaN          NaN
# 4170    0.000     0.000    0.000     NaN              457.0         9.60
# 4183    0.000     0.000    0.000     NaN               80.0         0.00
# 4192   41.042     0.000   41.042     NaN                NaN          NaN
#
# [1179 rows x 15 columns]

# %%
# fill na's with 0 
# i assume that if they didn't fill it out, there is nothing to report
df_19 = df_19.fillna(0).reset_index(drop=True)

# %%
df_19
# Out:
#                                        name state  total_mwh  total_cust  \
# 0                       A & N Electric Coop    MD     2623.0       316.0
# 1                       A & N Electric Coop    VA   701387.0     35618.0
# 2                       Adams Electric Coop    IL   176102.0      8931.0
# 3              Adams-Columbia Electric Coop    WI   515186.0     37607.0
# 4                    Agralite Electric Coop    MN   238558.0      5251.0
# ...                                     ...   ...        ...         ...
# 1174             City of Winter Park - (FL)    FL   425022.0     15565.0
# 1175           PUD No 1 of Jefferson County    WA   376212.0     19742.0
# 1176          CKenergy Electric Cooperative    OK   654238.0     25684.0
# 1177  Upper Michigan Energy Resources Corp.    MI  1610240.0     36818.0
# 1178      Southern Pioneer Electric Company    KS   817910.0     16939.0
#
#            no                   type saidi_nomed saifi_nomed caidi_nomed  \
# 0        84.0            Cooperative           .           .           .
# 1        84.0            Cooperative           .           .           .
# 2        97.0            Cooperative      169.74        1.29     131.581
# 3       108.0            Cooperative       139.9        0.95     147.263
# 4       155.0            Cooperative     128.759       1.181     109.025
# ...       ...                    ...         ...         ...         ...
# 1174  58124.0              Municipal           .           .           .
# 1175  59013.0  Political Subdivision         291        2.04     142.647
# 1176  60482.0            Cooperative           .           .           .
# 1177  60631.0         Investor Owned         238         1.5     158.667
# 1178  60839.0            Cooperative      106.41           .           .
#
#        pv_mwh  wind_mwh   nm_mwh  ee_mwh  dem_res_customers  dem_res_mwh
# 0       0.000     0.000    0.000    0.00               35.0         1.05
# 1       0.000     0.000    0.000    0.00             2101.0        63.03
# 2       0.000     0.000    0.000    0.00             4402.0         0.00
# 3     705.775    22.235  728.010    0.00             4781.0     13647.36
# 4       0.000     0.000    0.000    0.00                0.0         0.00
# ...       ...       ...      ...     ...                ...          ...
# 1174  401.337     0.000  401.337   15.18                0.0         0.00
# 1175    0.000     0.000    0.000  651.00                0.0         0.00
# 1176    0.000     0.000    0.000    0.00              457.0         9.60
# 1177    0.000     0.000    0.000    0.00               80.0         0.00
# 1178   41.042     0.000   41.042    0.00                0.0         0.00
#
# [1179 rows x 15 columns]

# %% [markdown]
# ### Make the percentage net metering, energy efficiency, and demand response columns.

# %%
df_19['pv_pct'] = ((df_19['pv_mwh']/df_19['total_mwh']) * 100).fillna(0)

# %%
df_19['wind_pct'] = ((df_19['wind_mwh']/df_19['total_mwh']) * 100).fillna(0)

# %%
df_19['nm_pct'] = ((df_19['nm_mwh']/df_19['total_mwh']) * 100).fillna(0)

# %%
df_19['ee_pct'] = ((df_19['ee_mwh']/df_19['total_mwh']) * 100).fillna(0)

# %%
df_19['dem_res_pct'] = ((df_19['dem_res_mwh']/df_19['total_mwh']) * 100).fillna(0)

# %%
df_19['dem_res_cust_pct'] = ((df_19['dem_res_customers']/df_19['total_cust']) * 100).fillna(0)

# %%
df_19.describe()
# Out:
#           total_mwh    total_cust            no         pv_mwh      wind_mwh  \
# count  1.179000e+03  1.179000e+03   1179.000000    1179.000000   1179.000000
# mean   2.297817e+06  1.055419e+05  12232.926209    1301.231873     56.712898
# std    7.320916e+06  3.393605e+05   8293.363602   16280.082379   1474.599677
# min    1.390000e+02  1.400000e+01     84.000000       0.000000      0.000000
# 25%    1.864190e+05  7.976500e+03   6177.000000       0.000000      0.000000
# 50%    4.370350e+05  1.845600e+04  12296.000000       0.000000      0.000000
# 75%    1.074674e+06  4.884250e+04  16667.000000      18.968500      0.000000
# max    1.119557e+08  5.061483e+06  60839.000000  466156.237000  49255.057000
#
#               nm_mwh        ee_mwh  dem_res_customers    dem_res_mwh  \
# count    1179.000000  1.179000e+03        1179.000000    1179.000000
# mean     1363.256529  2.092600e+04        8562.232400    1189.138297
# std     17513.556961  1.071791e+05       56734.563621   28908.933160
# min         0.000000  0.000000e+00           0.000000       0.000000
# 25%         0.000000  0.000000e+00           0.000000       0.000000
# 50%         0.000000  0.000000e+00           0.000000       0.000000
# 75%        25.552500  7.277500e+02           5.500000       0.000000
# max    515411.294000  2.097423e+06      895133.000000  977215.000000
#
#             pv_pct     wind_pct       nm_pct       ee_pct  dem_res_pct  \
# count  1179.000000  1179.000000  1179.000000  1179.000000  1179.000000
# mean      0.055809     0.001832     0.058439     0.335131     0.019424
# std       0.436323     0.024302     0.448256     1.006991     0.166305
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.004714     0.000000     0.005699     0.185870     0.000000
# max      10.630452     0.758238    10.630452    14.156696     3.509534
#
#        dem_res_cust_pct
# count       1179.000000
# mean           3.957544
# std           12.387149
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.007353
# max          100.000000

# %% [markdown]
# ### Need to justify using SAIDI rather than SAIFI or CAIDI

# %% [markdown]
# There are 766 entries for SAIDI, and only about 705 for SAIFI and CAIDI. Therefore, I will be using SAIDI as my index for grid reliability.

# %%
# limit dataframe to SAIDI, which has the most nonzero entries (770) 
df_19 = df_19[(df_19.saidi_nomed != '.')].reset_index(drop=True)

# %%
df_19.describe()
# Out:
#           total_mwh    total_cust            no         pv_mwh      wind_mwh  \
# count  7.670000e+02  7.670000e+02    767.000000     767.000000    767.000000
# mean   2.877815e+06  1.325098e+05  12300.241199    1550.214467     85.972602
# std    8.153767e+06  3.853289e+05   8559.434421   18568.005573   1827.782954
# min    2.829000e+03  4.100000e+01     97.000000       0.000000      0.000000
# 25%    2.374375e+05  1.095350e+04   5896.000000       0.000000      0.000000
# 50%    5.314040e+05  2.415200e+04  12268.000000       0.000000      0.000000
# 75%    1.484748e+06  6.527150e+04  16715.000000      61.572000      0.000000
# max    1.119557e+08  5.061483e+06  60839.000000  466156.237000  49255.057000
#
#               nm_mwh        ee_mwh  dem_res_customers    dem_res_mwh  \
# count     767.000000  7.670000e+02         767.000000     767.000000
# mean     1643.750449  2.754904e+04       12274.062581    1751.307789
# std     20219.404253  1.255740e+05       69746.807005   35827.024220
# min         0.000000  0.000000e+00           0.000000       0.000000
# 25%         0.000000  0.000000e+00           0.000000       0.000000
# 50%         0.000000  0.000000e+00           0.000000       0.000000
# 75%        67.811500  1.209000e+03          31.500000       0.000000
# max    515411.294000  2.097423e+06      895133.000000  977215.000000
#
#            pv_pct    wind_pct      nm_pct      ee_pct  dem_res_pct  \
# count  767.000000  767.000000  767.000000  767.000000   767.000000
# mean     0.063395    0.002529    0.067048    0.368537     0.018130
# std      0.496224    0.029555    0.512212    1.061427     0.179930
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000    0.000000     0.000000
# 50%      0.000000    0.000000    0.000000    0.000000     0.000000
# 75%      0.007916    0.000000    0.008568    0.237313     0.000000
# max     10.630452    0.758238   10.630452   10.727103     3.509534
#
#        dem_res_cust_pct
# count        767.000000
# mean           4.560795
# std           13.820391
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.035619
# max          100.000000

# %%
df_19.drop('')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               767 non-null    object
#  1   state              767 non-null    object
#  2   total_mwh          767 non-null    float64
#  3   total_cust         767 non-null    float64
#  4   no                 767 non-null    float64
#  5   type               767 non-null    object
#  6   saidi_nomed        767 non-null    object
#  7   saifi_nomed        767 non-null    object
#  8   caidi_nomed        767 non-null    object
#  9   pv_mwh             767 non-null    float64
#  10  wind_mwh           767 non-null    float64
#  11  nm_mwh             767 non-null    float64
#  12  ee_mwh             767 non-null    float64
#  13  dem_res_customers  767 non-null    float64
#  14  dem_res_mwh        767 non-null    float64
#  15  pv_pct             767 non-null    float64
#  16  wind_pct           767 non-null    float64
#  17  nm_pct             767 non-null    float64
#  18  ee_pct             767 non-null    float64
#  19  dem_res_pct        767 non-null    float64
#  20  dem_res_cust_pct   767 non-null    float64
# dtypes: float64(15), object(6)
# memory usage: 126.0+ KB

# %%
df_19.sort_values(by='name')
# Out:
#                                name state  total_mwh  total_cust       no  \
# 220    4-County Electric Power Assn    MS  1090317.0     48915.0   6641.0
# 400                    ALLETE, Inc.    MN  9014805.0    147340.0  12647.0
# 0               Adams Electric Coop    IL   176102.0      8931.0     97.0
# 1      Adams-Columbia Electric Coop    WI   515186.0     37607.0    108.0
# 2            Agralite Electric Coop    MN   238558.0      5251.0    155.0
# ..                              ...   ...        ...         ...      ...
# 721                 Wyrulec Company    WY   171783.0      4822.0  21079.0
# 720                 Wyrulec Company    NE    18771.0       499.0  21079.0
# 719           Y-W Electric Assn Inc    CO   335317.0      8783.0  21075.0
# 722  Yampa Valley Electric Assn Inc    CO   552803.0     27065.0  21081.0
# 718          York Electric Coop Inc    SC  1070398.0     62320.0  21002.0
#
#                type saidi_nomed saifi_nomed caidi_nomed    pv_mwh  ...  \
# 220     Cooperative      125.82        1.47     85.5918     0.000  ...
# 400  Investor Owned      144.02        1.35     106.681   572.602  ...
# 0       Cooperative      169.74        1.29     131.581     0.000  ...
# 1       Cooperative       139.9        0.95     147.263   705.775  ...
# 2       Cooperative     128.759       1.181     109.025     0.000  ...
# ..              ...         ...         ...         ...       ...  ...
# 721     Cooperative     164.019       1.128     145.407     0.000  ...
# 720     Cooperative     353.521       2.228     158.672     0.000  ...
# 719     Cooperative        62.7           .           .     2.523  ...
# 722     Cooperative       203.5       2.421     84.0562     0.000  ...
# 718     Cooperative       72.27       0.722     100.097  1930.000  ...
#
#        nm_mwh   ee_mwh  dem_res_customers  dem_res_mwh    pv_pct  wind_pct  \
# 220     0.000      0.0                0.0         0.00  0.000000  0.000000
# 400   577.929  61243.0             7897.0       746.00  0.006352  0.000059
# 0       0.000      0.0             4402.0         0.00  0.000000  0.000000
# 1     728.010      0.0             4781.0     13647.36  0.136994  0.004316
# 2       0.000      0.0                0.0         0.00  0.000000  0.000000
# ..        ...      ...                ...          ...       ...       ...
# 721     0.000      0.0                0.0         0.00  0.000000  0.000000
# 720     0.000      0.0                0.0         0.00  0.000000  0.000000
# 719     2.523    112.7                0.0         0.00  0.000752  0.000000
# 722     0.000      0.0                0.0         0.00  0.000000  0.000000
# 718  1930.000    398.0             5637.0         0.00  0.180307  0.000000
#
#        nm_pct    ee_pct  dem_res_pct  dem_res_cust_pct
# 220  0.000000  0.000000     0.000000          0.000000
# 400  0.006411  0.679360     0.008275          5.359712
# 0    0.000000  0.000000     0.000000         49.288993
# 1    0.141310  0.000000     2.649016         12.713059
# 2    0.000000  0.000000     0.000000          0.000000
# ..        ...       ...          ...               ...
# 721  0.000000  0.000000     0.000000          0.000000
# 720  0.000000  0.000000     0.000000          0.000000
# 719  0.000752  0.033610     0.000000          0.000000
# 722  0.000000  0.000000     0.000000          0.000000
# 718  0.180307  0.037182     0.000000          9.045250
#
# [767 rows x 21 columns]

# %%
# make sure we're good to go
msno.matrix(df_19)

# %%
# export as CSV so I can use it in my next step
df_19.to_csv("df_19.csv",index=False)

# %% [markdown]
# ## Unresolved pile

# %%
# when we mergeed our dataframes, they dropped all the adjustments
# we decide to ignore these based on expert feedback
net_metering_19[net_metering_19['name'].str.contains("Adjustment")]

# %% [markdown]
# # Discard pile

# %%
#rel_ut = reliability_19.merge(utility_19, on = ["name","state"])

# %%
#rel_ut.merge(utility_19, on = ["name","state"])

# %%
# was going to use to merge columns but not necessary
#cols = [col for col in net_metering_19.columns if 'Unnamed:' not in col]
